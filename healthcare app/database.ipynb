# %%
import pandas as pd
import numpy as np

# %%
file_path = '/home/ubuntu/Desktop/salary.csv'

df = pd.read_csv(file_path)

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  16534.000000  1.653400e+04   16534.000000  16534.000000
# mean    2023.226866  1.637270e+05  149686.777973     32.003750
# std        0.713558  3.402057e+05   68505.293156     46.245158
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.017630e+05  101125.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.872000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
filtered_column = df['salary_currency'] == 'USD'
df = df[filtered_column]
df
top_10_salaries = df.nlargest(25, 'salary_in_usd')
print(top_10_salaries)
# Out:
#       work_year experience_level employment_type                   job_title  \
# 2804       2024               MI              FT                AI Architect
# 3647       2024               EN              FT                Data Analyst
# 4446       2024               SE              FT          Analytics Engineer
# 4622       2024               MI              FT  Machine Learning Scientist
# 5033       2024               SE              FT                Data Analyst
# 5808       2024               MI              FT  Machine Learning Scientist
# 6406       2023               MI              FT  Machine Learning Scientist
# 6412       2023               MI              FT   Machine Learning Engineer
# 7390       2023               MI              FT               Data Engineer
# 7498       2023               SE              FT              Data Scientist
# 393        2024               SE              FT          Analytics Engineer
# ...

# %%
import requests
import json

url = 'https://api.exchangerate-api.com/v4/latest/NIO'
response = requests.get(url)
data = response.text
parsed = json.loads(data)
print(json.dumps(parsed, indent=4))
# Out:
# {
#     "provider": "https://www.exchangerate-api.com",
#     "WARNING_UPGRADE_TO_V6": "https://www.exchangerate-api.com/docs/free",
#     "terms": "https://www.exchangerate-api.com/terms",
#     "base": "NIO",
#     "date": "2024-06-19",
#     "time_last_updated": 1718755201,
#     "rates": {
#         "NIO": 1,
#         "AED": 0.1,
#         "AFN": 1.92,
#         "ALL": 2.55,
#         "AMD": 10.53,
#         "ANG": 0.0487,
#         "AOA": 23.45,
#         "ARS": 24.64,
#         "AUD": 0.0412,
#         "AWG": 0.0487,
#         "AZN": 0.0463,
#         "BAM": 0.0497,
#         "BBD": 0.0544,
#         "BDT": 3.2,
#         "BGN": 0.0497,
#         "BHD": 0.0102,
#         "BIF": 77.88,
#         "BMD": 0.0272,
#         "BND": 0.0369,
#         "BOB": 0.188,
#         "BRL": 0.148,
#         "BSD": 0.0272,
#         "BTN": 2.27,
#         "BWP": 0.369,
#         "BYN": 0.0891,
#         "BZD": 0.0544,
#         "CAD": 0.0374,
#         "CDF": 76.94,
#         "CHF": 0.0242,
# ...

# %%
file_path = '/home/ubuntu/Desktop/Python/patient_info.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#     Name Lastname  Age    Weight  Height        BMI Health Status
# 0  Kevin  Cromley   22  70.30676  1.8288  21.021546        Normal

# %%
df1 = pd.read_csv('/home/ubuntu/Desktop/salary.csv')
df2 = pd.read_csv('/home/ubuntu/Desktop/Python/patient_info.csv')


df3 = pd.concat([df1, df2], axis=0)


df3.to_csv('/home/ubuntu/Desktop/Python/combined.csv', index=False)
